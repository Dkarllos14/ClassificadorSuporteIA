# %%
import pandas as pd
import os

# Caminho absoluto direto para o novo local no C:
caminho_dados = r'C:\ClassificadorSuporteIA\data\chamados.csv'

if os.path.exists(caminho_dados):
    df = pd.read_csv(caminho_dados)
    print("✅ Sucesso! Dados carregados do novo local.")
    display(df.head())
else:
    print(f"❌ Erro: Arquivo não encontrado em {caminho_dados}")
# Out:
# ✅ Sucesso! Dados carregados do novo local.
#    id        data    cliente                    assunto  \
# 0   1  2024-03-01  Empresa A              Erro de Login
# 1   2  2024-03-01  Empresa B  Lentidão na Base de Dados
# 2   3  2024-03-02  Empresa C        Configuração de VPN
# 3   4  2024-03-02  Empresa A         Impressora Offline
# 4   5  2024-03-03  Empresa D      Pedido de Novo Acesso
#
#                                            descricao prioridade
# 0  Utilizador não consegue aceder ao sistema, apa...       Alta
# 1  O dashboard de vendas está a demorar mais de 3...      Media
# 2  Solicitação de auxílio para configurar o novo ...      Baixa
# 3  A impressora do setor financeiro parou de resp...      Media
# 4  Criar conta de utilizador para novo colaborado...      Baixa

# %%
print("--- Diagnóstico dos Dados ---")
df.info()

print("\n--- Volume por Prioridade ---")
print(df['prioridade'].value_counts())
# Out:
# --- Diagnóstico dos Dados ---
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          6 non-null      int64
#  1   data        6 non-null      str
#  2   cliente     6 non-null      str
#  3   assunto     6 non-null      str
#  4   descricao   6 non-null      str
#  5   prioridade  6 non-null      str
# dtypes: int64(1), str(5)
# memory usage: 420.0 bytes
#
# --- Volume por Prioridade ---
# prioridade
# Media      2
# Baixa      2
# Alta       1
# Critica    1
# Name: count, dtype: int64

# %%
# Criando a coluna consolidada para a IA ler
df['texto_para_ia'] = df['assunto'] + " | " + df['descricao']

print("--- Exemplo de entrada consolidada ---")
print(df['texto_para_ia'].iloc[0])
# Out:
# --- Exemplo de entrada consolidada ---
# Erro de Login | Utilizador não consegue aceder ao sistema, aparece mensagem de password incorreta mesmo após reset.
